# %% [markdown]
# Cache缓存

# %%
from langchain_openai import ChatOpenAI

chat=ChatOpenAI(
  model="qwen2.5-coder-1.5b-instruct",
  openai_api_key="EMPTY",
  base_url="http://127.0.0.1:1234/v1",
  temperature=0.7
)

response=chat.invoke("请问两只兔子有多少条腿")
response.content
# Out:
# '两只兔子各有两条腿。所以，两只兔子一共有2 + 2 = 4条腿。'

# %%
# %%time
from langchain.globals import set_llm_cache
from langchain_core.caches import InMemoryCache

set_llm_cache(InMemoryCache())
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
# %%time
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
output_parser=StrOutputParser()

prompt=ChatPromptTemplate.from_template("请根据下面的主题写一篇小红书营销的短文:{topic}")

chain=prompt | chat | output_parser

chain.invoke({"topic":"康师傅绿茶"})
# Out:
# CPU times: total: 31.2 ms
# Wall time: 5.26 s
# '标题：康师傅绿茶，你的生活，从这里开始！\n\n康师傅，中国品牌茶饮大家庭的一员，一直以高品质、好味道闻名于世。今天，我就来带大家一起品鉴康师傅绿茶的魅力。\n\n首先，康师傅绿茶的包装设计简洁明了，以清新绿叶为主题，色彩搭配和谐，让人一眼就能感受到茶叶的清新和健康。每一包都装有10克的包装，方便大家随时随地享用。\n\n其次，康师傅绿茶的口感独特，茶香四溢，回味无穷。无论是冲泡还是煮饮，都能让你享受到一杯清新的绿茶带来的美妙体验。它的茶汤清澈透明，颜色鲜亮，给人一种清新脱俗的感觉。\n\n再次，康师傅绿茶的营养丰富，富含蛋白质、维生素和矿物质等，对身体健康非常有益。特别是对于追求健康的人群来说，康师傅绿茶是一个不错的选择。\n\n最后，康师傅绿茶的价格实惠，性价比高，无论是作为日常茶饮还是馈赠亲友，都能让你得到满意的结果。康师傅绿茶，你值得尝试！'

# %%
# %%time
chain.invoke({"topic":"康师傅绿茶"})
# Out:
# CPU times: total: 0 ns
# Wall time: 2 ms
# '标题：康师傅绿茶，你的生活，从这里开始！\n\n康师傅，中国品牌茶饮大家庭的一员，一直以高品质、好味道闻名于世。今天，我就来带大家一起品鉴康师傅绿茶的魅力。\n\n首先，康师傅绿茶的包装设计简洁明了，以清新绿叶为主题，色彩搭配和谐，让人一眼就能感受到茶叶的清新和健康。每一包都装有10克的包装，方便大家随时随地享用。\n\n其次，康师傅绿茶的口感独特，茶香四溢，回味无穷。无论是冲泡还是煮饮，都能让你享受到一杯清新的绿茶带来的美妙体验。它的茶汤清澈透明，颜色鲜亮，给人一种清新脱俗的感觉。\n\n再次，康师傅绿茶的营养丰富，富含蛋白质、维生素和矿物质等，对身体健康非常有益。特别是对于追求健康的人群来说，康师傅绿茶是一个不错的选择。\n\n最后，康师傅绿茶的价格实惠，性价比高，无论是作为日常茶饮还是馈赠亲友，都能让你得到满意的结果。康师傅绿茶，你值得尝试！'

# %% [markdown]
# SQLite缓存

# %%
from langchain_community.cache import SQLiteCache

set_llm_cache(SQLiteCache(database_path=".langchain.db"))

# %%
# %%time
chain.invoke({"topic":"旺仔小馒头"})
# Out:
# CPU times: total: 15.6 ms
# Wall time: 4.65 s
# '旺仔小馒头，你的早餐好伙伴！每个清晨，我都会和家人一起品尝这香甜可口的小馒头。无论是早上起床后的一碗热腾腾的小馒头，还是下午在学校里的午餐，都能让我感到满满的满足感。\n\n旺仔小馒头不仅味道鲜美，而且营养丰富。它富含蛋白质、碳水化合物和维生素B群，能够提供身体所需的能量。同时，它还含有大量的膳食纤维，有助于消化和预防便秘。\n\n作为早餐的首选，旺仔小馒头能够迅速唤醒你的大脑，让你在忙碌的一天中保持清醒和精神饱满。而作为午餐的主食，它能为你的身体提供持续的能量，帮助你顺利完成学习和工作。\n\n除此之外，旺仔小馒头还具有很高的营养价值，适合各个年龄段的人群食用。无论是成人还是儿童，都能从中获得足够的能量和营养，保证身体健康。\n\n总的来说，旺仔小馒头是一款非常受欢迎的小食品，它的香甜可口、营养丰富，深受大家的喜爱。如果你喜欢这款产品，不妨来试试吧！'

# %%
# %%time
chain.invoke({"topic":"旺仔小馒头"})
# Out:
# CPU times: total: 0 ns
# Wall time: 5.63 ms
# '旺仔小馒头，你的早餐好伙伴！每个清晨，我都会和家人一起品尝这香甜可口的小馒头。无论是早上起床后的一碗热腾腾的小馒头，还是下午在学校里的午餐，都能让我感到满满的满足感。\n\n旺仔小馒头不仅味道鲜美，而且营养丰富。它富含蛋白质、碳水化合物和维生素B群，能够提供身体所需的能量。同时，它还含有大量的膳食纤维，有助于消化和预防便秘。\n\n作为早餐的首选，旺仔小馒头能够迅速唤醒你的大脑，让你在忙碌的一天中保持清醒和精神饱满。而作为午餐的主食，它能为你的身体提供持续的能量，帮助你顺利完成学习和工作。\n\n除此之外，旺仔小馒头还具有很高的营养价值，适合各个年龄段的人群食用。无论是成人还是儿童，都能从中获得足够的能量和营养，保证身体健康。\n\n总的来说，旺仔小馒头是一款非常受欢迎的小食品，它的香甜可口、营养丰富，深受大家的喜爱。如果你喜欢这款产品，不妨来试试吧！'
