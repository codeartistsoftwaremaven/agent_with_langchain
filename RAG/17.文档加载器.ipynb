# %%
from langchain_community.document_loaders import TextLoader

loader=TextLoader("huawei_service.txt",encoding="utf-8")
doc=loader.load()
doc
# Out:
# [Document(metadata={'source': 'huawei_service.txt'}, page_content='华为商城（VMALL）退换货服务政策\n1. 总则\n\n华为商城严格遵循国家《三包》法规，针对在商城购买的终端产品（手机、平板、穿戴、智能家居等）提供“7天无理由退货、15天换货、一年保修”的售后保障服务。\n2. 退换货时效\n\n    7天无理由退货：自收货次日起 7 天内，在商品完好（未激活、无受损）的情况下可申请退货。\n\n    15天质量问题换货：自收货次日起 15 天内，若产品出现性能故障，经华为官方售后检测属实，可免费更换同型号同规格的新机。\n\n    一年保修：自收货次日起一年内，商品出现非人为损坏的性能故障，提供免费维修服务。\n\n3. “商品完好”判定标准\n\n申请 7 天无理由退货时，需满足以下条件：\n\n    产品未激活：手机、平板等涉及系统激活的产品，一旦联网激活，非质量问题不支持退货。\n\n    外观完好：产品机身、配件无划痕、无磨损、无拆解记录。\n\n    包装完整：外包装、说明书、保修卡、发票及赠品需一并退回。\n\n4. 特殊产品限制\n\n    个性化定制产品：如激光刻字版、特殊定制外壳产品，非质量问题不支持 7 天无理由退货。\n\n    卫生敏感类产品：如入耳式耳机，若包装封条已拆封且无质量问题，出于卫生考虑不支持退货。\n\n5. 退款流程\n\n    提交申请：在“我的订单”中点击“申请售后”，上传商品实拍照片。\n\n    寄回商品：审核通过后，用户需将商品寄回指定仓库（部分地区支持顺丰上门取件）。\n\n    仓库质检：收货后 1-3 个工作日内完成检测。\n\n    退款到账：质检合格后，款项将按原支付路径退回，预计 3-5 个工作日到账。')]

# %%
loader1=TextLoader("huawei_installment.txt",encoding="utf-8")
doc1=loader1.load()
doc1
# Out:
# [Document(metadata={'source': 'huawei_installment.txt'}, page_content='华为商城（VMALL）分期付款业务指南\n1. 业务概述\n\n华为分期是华为商城联合各大银行及金融机构（如花呗、招商银行、平安银行等）推出的“先消费、后付款”的金融服务。用户在购买华为产品（如 Mate 60 系列、Pura 系列等）时，可将订单金额分为若干期缴纳。\n2. 支付方式与渠道\n\n目前华为商城支持以下主流分期工具：\n\n    花呗分期：支持 3 期、6 期、12 期。\n\n    银行信用卡分期：\n\n        合作银行：招商银行、中国工商银行、中国建设银行、中国农业银行等。\n\n        可选期数：通常提供 3、6、12、24 期选择。\n\n    掌上生活/其它银行 App 支付：通过跳转银行原生 App 完成分期操作。\n\n3. 费率与优惠说明\n3.1 费率标准\n\n    手续费计算：每期还款额 = 订单总金额 ÷ 分期期数 + 手续费。\n\n    费率浮动：具体手续费率以支付页面显示为准，不同银行费率略有差异。\n\n3.2 免息活动（重要）\n\n    0 首付 0 利息 0 手续费：华为经常针对新品推出“限时免息”活动。\n\n    适用条件：需满足指定的订单金额门槛（例如满 499 元可用）或指定机型。\n\n4. 办理流程\n\n    提交订单：在华为商城选择商品，进入结算页面。\n\n    选择分期：在支付方式中勾选“分期支付”。\n\n    确认期数：选择具体的期数（如 12 期免息），系统会实时显示每期应还金额。\n\n    身份验证：跳转至对应的支付平台（如支付宝或银行 H5 页面）进行生物识别或密码确认。\n\n    支付成功：订单状态更新为“待发货”。\n\n5. 常见问题 (FAQ)\n\n    Q：分期后可以提前还款吗？\n\n        A：可以。但部分银行可能会收取提前还款手续费，建议咨询发卡行。\n\n    Q：申请分期退货后，利息怎么算？\n\n        A：订单全额退款后，已收取的费用通常会按银行规则退回，未产生的期数自动取消。\n\n    Q：为什么我无法选择 24 期分期？\n\n       
# ...

# %%
loader2=TextLoader("huawei_hormony.md",encoding="utf-8")
doc2=loader2.load()
doc2
# Out:
# [Document(metadata={'source': 'huawei_hormony.md'}, page_content='华为 HarmonyOS 升级指南与兼容性说明\n1. 什么是 HarmonyOS？\n\nHarmonyOS（鸿蒙系统）是华为研发的面向全场景的分布式操作系统。它通过“分布式技术”让多个设备（手机、平板、手表、电脑）可以像一台设备一样协同工作，支持超级终端、万能卡片等核心功能。\n2. 升级前准备工作\n\n在进行系统升级前，请务必完成以下操作：\n\n    数据备份：建议通过“华为云空间”或“手机助手”备份微信聊天记录、联系人及重要照片。\n\n    空间清理：确保手机剩余存储空间在 10GB 以上。\n\n    电量检查：电池电量需保持在 50% 以上，或连接充电器。\n\n    环境检查：手机不能有 Root 记录，否则无法收到官方 OTA 推送。\n\n3. 兼容设备列表（首批及主要型号）\n\n以下机型现已全面开放正式版升级：\n\n    Mate 系列：Mate 60 全系列、Mate 50 全系列、Mate 40 系列、Mate X5/X3 折叠屏。\n\n    P/Pura 系列：Pura 70 全系列、P/Pura 60 系列、P50 系列。\n\n    Nova 系列：Nova 12 全系列、Nova 11 系列。\n\n    平板系列：MatePad Pro 13.2 英寸、MatePad Air。\n\n4. 如何进行升级？\n\n用户可以通过以下两种路径获取最新系统：\n\n    路径 A（设置更新）：进入“设置” -> “系统和更新” -> “软件更新” -> “检查更新”。\n\n    路径 B（我的华为）：打开“我的华为” App -> 点击首页“升级尝鲜” -> 检查符合条件的版本。\n\n5. 常见问题解答 (FAQ)\n\n    Q：升级后手机发热、卡顿正常吗？\n\n        A：正常。升级后的 2-3 天内，系统会在后台进行自优化（如文件索引重建、碎片整理），建议在夜间充电时亮屏静置 2 小时。\n\n    Q：升级后我的 Android 应用还能用吗？\n\n        A：目前的版本依然兼容大部分主流 Android 应用（APK 格式），请放心使用。
# ...

# %%
from langchain_community.vectorstores import FAISS
from langchain_openai import OpenAIEmbeddings

embeddings=OpenAIEmbeddings(
  base_url="http://127.0.0.1:1234/v1",
  openai_api_key="lm-studio",
  model="text-embedding-bge-large-zh-v1.5",
  check_embedding_ctx_length=False
)

# %%
vectorstoreDB=FAISS.from_documents([doc[0],doc1[0],doc2[0]],embeddings)
vectorstoreDB

# %%
vectorstoreDB.similarity_search("手机退换货，应该怎么操作")
# Out:
# [Document(metadata={'source': 'huawei_service.txt'}, page_content='华为商城（VMALL）退换货服务政策\n1. 总则\n\n华为商城严格遵循国家《三包》法规，针对在商城购买的终端产品（手机、平板、穿戴、智能家居等）提供“7天无理由退货、15天换货、一年保修”的售后保障服务。\n2. 退换货时效\n\n    7天无理由退货：自收货次日起 7 天内，在商品完好（未激活、无受损）的情况下可申请退货。\n\n    15天质量问题换货：自收货次日起 15 天内，若产品出现性能故障，经华为官方售后检测属实，可免费更换同型号同规格的新机。\n\n    一年保修：自收货次日起一年内，商品出现非人为损坏的性能故障，提供免费维修服务。\n\n3. “商品完好”判定标准\n\n申请 7 天无理由退货时，需满足以下条件：\n\n    产品未激活：手机、平板等涉及系统激活的产品，一旦联网激活，非质量问题不支持退货。\n\n    外观完好：产品机身、配件无划痕、无磨损、无拆解记录。\n\n    包装完整：外包装、说明书、保修卡、发票及赠品需一并退回。\n\n4. 特殊产品限制\n\n    个性化定制产品：如激光刻字版、特殊定制外壳产品，非质量问题不支持 7 天无理由退货。\n\n    卫生敏感类产品：如入耳式耳机，若包装封条已拆封且无质量问题，出于卫生考虑不支持退货。\n\n5. 退款流程\n\n    提交申请：在“我的订单”中点击“申请售后”，上传商品实拍照片。\n\n    寄回商品：审核通过后，用户需将商品寄回指定仓库（部分地区支持顺丰上门取件）。\n\n    仓库质检：收货后 1-3 个工作日内完成检测。\n\n    退款到账：质检合格后，款项将按原支付路径退回，预计 3-5 个工作日到账。'),
# ...

# %%
vectorstoreDB.similarity_search_with_relevance_scores("手机退换货，应该怎么操作")
# Out:
# [(Document(metadata={'source': 'huawei_service.txt'}, page_content='华为商城（VMALL）退换货服务政策\n1. 总则\n\n华为商城严格遵循国家《三包》法规，针对在商城购买的终端产品（手机、平板、穿戴、智能家居等）提供“7天无理由退货、15天换货、一年保修”的售后保障服务。\n2. 退换货时效\n\n    7天无理由退货：自收货次日起 7 天内，在商品完好（未激活、无受损）的情况下可申请退货。\n\n    15天质量问题换货：自收货次日起 15 天内，若产品出现性能故障，经华为官方售后检测属实，可免费更换同型号同规格的新机。\n\n    一年保修：自收货次日起一年内，商品出现非人为损坏的性能故障，提供免费维修服务。\n\n3. “商品完好”判定标准\n\n申请 7 天无理由退货时，需满足以下条件：\n\n    产品未激活：手机、平板等涉及系统激活的产品，一旦联网激活，非质量问题不支持退货。\n\n    外观完好：产品机身、配件无划痕、无磨损、无拆解记录。\n\n    包装完整：外包装、说明书、保修卡、发票及赠品需一并退回。\n\n4. 特殊产品限制\n\n    个性化定制产品：如激光刻字版、特殊定制外壳产品，非质量问题不支持 7 天无理由退货。\n\n    卫生敏感类产品：如入耳式耳机，若包装封条已拆封且无质量问题，出于卫生考虑不支持退货。\n\n5. 退款流程\n\n    提交申请：在“我的订单”中点击“申请售后”，上传商品实拍照片。\n\n    寄回商品：审核通过后，用户需将商品寄回指定仓库（部分地区支持顺丰上门取件）。\n\n    仓库质检：收货后 1-3 个工作日内完成检测。\n\n    退款到账：质检合格后，款项将按原支付路径退回，预计 3-5 个工作日到账。'),
#   0.3371163896693873),
# ...

# %%
import nltk
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\86151\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# 目录加载器

# %%
from langchain_community.document_loaders import DirectoryLoader

loader=DirectoryLoader("documents")
docs=loader.load()
docs
# Out:
# libmagic is unavailable but assists in filetype detection. Please consider installing libmagic for better results.
# libmagic is unavailable but assists in filetype detection. Please consider installing libmagic for better results.
# libmagic is unavailable but assists in filetype detection. Please consider installing libmagic for better results.
# ...

# %%
vectorstoreDB=FAISS.from_documents(docs,embeddings)
vectorstoreDB

# %%
vectorstoreDB.similarity_search_with_score("手机退换货，应该怎么操作")
# Out:
# [(Document(metadata={'source': 'documents\\huawei_service.txt'}, page_content='华为商城（VMALL）退换货服务政策\n\n1. 总则\n\n华为商城严格遵循国家《三包》法规，针对在商城购买的终端产品（手机、平板、穿戴、智能家居等）提供“7天无理由退货、15天换货、一年保修”的售后保障服务。\n\n2. 退换货时效\n\n7天无理由退货：自收货次日起 7 天内，在商品完好（未激活、无受损）的情况下可申请退货。\n\n15天质量问题换货：自收货次日起 15 天内，若产品出现性能故障，经华为官方售后检测属实，可免费更换同型号同规格的新机。\n\n一年保修：自收货次日起一年内，商品出现非人为损坏的性能故障，提供免费维修服务。\n\n3. “商品完好”判定标准\n\n申请 7 天无理由退货时，需满足以下条件：\n\n产品未激活：手机、平板等涉及系统激活的产品，一旦联网激活，非质量问题不支持退货。\n\n外观完好：产品机身、配件无划痕、无磨损、无拆解记录。\n\n包装完整：外包装、说明书、保修卡、发票及赠品需一并退回。\n\n4. 特殊产品限制\n\n个性化定制产品：如激光刻字版、特殊定制外壳产品，非质量问题不支持 7 天无理由退货。\n\n卫生敏感类产品：如入耳式耳机，若包装封条已拆封且无质量问题，出于卫生考虑不支持退货。\n\n5. 退款流程\n\n提交申请：在“我的订单”中点击“申请售后”，上传商品实拍照片。\n\n寄回商品：审核通过后，用户需将商品寄回指定仓库（部分地区支持顺丰上门取件）。\n\n仓库质检：收货后 1\n\n3 个工作日内完成检测。\n\n退款到账：质检合格后，款项将按原支付路径退回，预计 3\n\n5 个工作日到账。'),
#   0.937459),
# ...

# %% [markdown]
# 最大边际相关性检索（MMR）

# %%
retriever=vectorstoreDB.as_retriever(
    search_type="mmr",
    search_kwargs={"k":1}
)

# %%
docs=retriever.get_relevant_documents("手机退换货，应该怎么操作")
docs
# Out:
# C:\Users\86151\AppData\Local\Temp\ipykernel_112972\2259654991.py:1: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   docs=retriever.get_relevant_documents("手机退换货，应该怎么操作")
# ...

# %% [markdown]
# 余玄相似度

# %%
retriever=vectorstoreDB.as_retriever(
    search_type="similarity_score_threshold",
    search_kwargs={"score_threshold":0.3}
)

# %%
docs=retriever.get_relevant_documents("手机退换货，应该怎么操作")
docs
# Out:
# [Document(metadata={'source': 'documents\\huawei_service.txt'}, page_content='华为商城（VMALL）退换货服务政策\n\n1. 总则\n\n华为商城严格遵循国家《三包》法规，针对在商城购买的终端产品（手机、平板、穿戴、智能家居等）提供“7天无理由退货、15天换货、一年保修”的售后保障服务。\n\n2. 退换货时效\n\n7天无理由退货：自收货次日起 7 天内，在商品完好（未激活、无受损）的情况下可申请退货。\n\n15天质量问题换货：自收货次日起 15 天内，若产品出现性能故障，经华为官方售后检测属实，可免费更换同型号同规格的新机。\n\n一年保修：自收货次日起一年内，商品出现非人为损坏的性能故障，提供免费维修服务。\n\n3. “商品完好”判定标准\n\n申请 7 天无理由退货时，需满足以下条件：\n\n产品未激活：手机、平板等涉及系统激活的产品，一旦联网激活，非质量问题不支持退货。\n\n外观完好：产品机身、配件无划痕、无磨损、无拆解记录。\n\n包装完整：外包装、说明书、保修卡、发票及赠品需一并退回。\n\n4. 特殊产品限制\n\n个性化定制产品：如激光刻字版、特殊定制外壳产品，非质量问题不支持 7 天无理由退货。\n\n卫生敏感类产品：如入耳式耳机，若包装封条已拆封且无质量问题，出于卫生考虑不支持退货。\n\n5. 退款流程\n\n提交申请：在“我的订单”中点击“申请售后”，上传商品实拍照片。\n\n寄回商品：审核通过后，用户需将商品寄回指定仓库（部分地区支持顺丰上门取件）。\n\n仓库质检：收货后 1\n\n3 个工作日内完成检测。\n\n退款到账：质检合格后，款项将按原支付路径退回，预计 3\n\n5 个工作日到账。')]

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough,RunnableParallel
from langchain_core.output_parsers import StrOutputParser

template="""
只根据以下文档回答问题：
{context}

问题：{question}
"""

prompt=ChatPromptTemplate.from_template(template)

output_parser=StrOutputParser()

# %%
from langchain_openai import ChatOpenAI,OpenAI

model=ChatOpenAI(
  model="qwen2.5-coder-1.5b-instruct",
  openai_api_key="EMPTY",
  base_url="http://127.0.0.1:1234/v1",
  temperature=0.3
)

# %%
chain=(
    {"context":retriever,"question":RunnablePassthrough()}
    | prompt
    | model
    | StrOutputParser()
)

for chunk in chain.stream("手机退换货怎么做"):
    print(chunk,end="")
# Out:
# 手机、平板等涉及系统激活的产品，一旦联网激活，非质量问题不支持退货。
